# %%
tag2idx = {
    "U-DESIG": 0,
    "U-PHONE": 1,
    "I-CERTIFICATION": 2,
    "O": 3,
    "I-UNI": 4,
    "U-GITHUB": 5,
    "I-PROJECT_DESCRIPTION": 6,
    "B-GRADUATION_YEAR": 7,
    "I-GRADUATION_YEAR": 8,
    "L-GITHUB": 9,
    "I-LOC": 10,
    "B-WORKING_DESCRIPTION": 11,
    "L-LOC": 12,
    "I-WORKING_COMPANY_EXPERIENCES": 13,
    "B-CERTIFICATION": 14,
    "I-NAME": 15,
    "[SEP]": 16,
    "U-WORKING_COMPANY_EXPERIENCES": 17,
    "L-UNI": 18,
    "B-WORKING_TIME_EXPERIENCES": 19,
    "L-PROJECT": 20,
    "B-PROJECT": 21,
    "B-NAME": 22,
    "I-WORKING_DESCRIPTION": 23,
    "L-TECHSTACK_SKILLS": 24,
    "U-TECHSTACK_SKILLS": 25,
    "B-DEG": 26,
    "U-LOC": 27,
    "L-WORKING_TIME_EXPERIENCES": 28,
    "L-CERTIFICATION": 29,
    "L-DEG": 30,
    "L-GRADUATION_YEAR": 31,
    "B-TECHSTACK_SKILLS": 32,
    "L-DESIG": 33,
    "L-WORKING_DESCRIPTION": 34,
    "I-DEG": 35,
    "I-PROJECT": 36,
    "U-EMAIL": 37,
    "I-TECHSTACK_SKILLS": 38,
    "L-PROJECT_DESCRIPTION": 39,
    "B-GITHUB": 40,
    "B-UNI": 41,
    "[CLS]": 42,
    "I-DESIG": 43,
    "B-DESIG": 44,
    "I-WORKING_TIME_EXPERIENCES": 45,
    "B-LOC": 46,
    "L-NAME": 47,
    "B-PROJECT_DESCRIPTION": 48,
    "B-WORKING_COMPANY_EXPERIENCES": 49,
    "L-WORKING_COMPANY_EXPERIENCES": 50,
    "U-GPA": 51,
    "U-CERTIFICATION": 52,
    "X": 53,
}

idx2tag = {
    0: "U-DESIG",
    1: "U-PHONE",
    2: "I-CERTIFICATION",
    3: "O",
    4: "I-UNI",
    5: "U-GITHUB",
    6: "I-PROJECT_DESCRIPTION",
    7: "B-GRADUATION_YEAR",
    8: "I-GRADUATION_YEAR",
    9: "L-GITHUB",
    10: "I-LOC",
    11: "B-WORKING_DESCRIPTION",
    12: "L-LOC",
    13: "I-WORKING_COMPANY_EXPERIENCES",
    14: "B-CERTIFICATION",
    15: "I-NAME",
    16: "[SEP]",
    17: "U-WORKING_COMPANY_EXPERIENCES",
    18: "L-UNI",
    19: "B-WORKING_TIME_EXPERIENCES",
    20: "L-PROJECT",
    21: "B-PROJECT",
    22: "B-NAME",
    23: "I-WORKING_DESCRIPTION",
    24: "L-TECHSTACK_SKILLS",
    25: "U-TECHSTACK_SKILLS",
    26: "B-DEG",
    27: "U-LOC",
    28: "L-WORKING_TIME_EXPERIENCES",
    29: "L-CERTIFICATION",
    30: "L-DEG",
    31: "L-GRADUATION_YEAR",
    32: "B-TECHSTACK_SKILLS",
    33: "L-DESIG",
    34: "L-WORKING_DESCRIPTION",
    35: "I-DEG",
    36: "I-PROJECT",
    37: "U-EMAIL",
    38: "I-TECHSTACK_SKILLS",
    39: "L-PROJECT_DESCRIPTION",
    40: "B-GITHUB",
    41: "B-UNI",
    42: "[CLS]",
    43: "I-DESIG",
    44: "B-DESIG",
    45: "I-WORKING_TIME_EXPERIENCES",
    46: "B-LOC",
    47: "L-NAME",
    48: "B-PROJECT_DESCRIPTION",
    49: "B-WORKING_COMPANY_EXPERIENCES",
    50: "L-WORKING_COMPANY_EXPERIENCES",
    51: "U-GPA",
    52: "U-CERTIFICATION",
    53: "X",
}

MAX_LEN = 512

# %%
# Load back the bert model
from pytorch_pretrained_bert import BertForTokenClassification

bert_out_address = "models"

bert_model = BertForTokenClassification.from_pretrained(
    bert_out_address, num_labels=len(tag2idx)
).cpu()

# %%
from pytorch_pretrained_bert import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-cased', do_lower_case=False)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 213450/213450 [00:03<00:00, 63766.30B/s]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
import torch
import numpy as np
from scipy.special import softmax

# %%
def bert_predict(cv_data:str):
    #Token id embedding, mask word embedding
    tokenized_texts=[]
    temp_token=[]

    #Add [CLS] at the front
    temp_token.append('[CLS]')
    token_list = tokenizer.tokenize(cv_data)

    for m, token in enumerate(token_list):
        temp_token.append(token)

    # Trim the token to fit the length requirement
    if len(temp_token) > MAX_LEN-1:
        temp_token = temp_token[:MAX_LEN-1]

    #Add [SEP] at the end
    temp_token.append('[SEP]')

    tokenized_texts.append(temp_token)

    #Make id embedding
    input_ids = pad_sequences([tokenizer.convert_tokens_to_ids(txt) for txt in tokenized_texts],
                              maxlen=MAX_LEN,dtype='long',truncating='post',padding='post')
    #Make mask embeeding -> For fine tune of predict, with token mask is 1, pad token is 0
    attention_masks=[[float(i>0) for i in ii] for ii in input_ids]
    segment_ids = [[0] * len(input_id) for input_id in input_ids]

    #Make embeddings into torch tensor
    input_ids=torch.tensor(input_ids)
    attention_masks=torch.tensor(attention_masks)
    segment_ids = torch.tensor(segment_ids)

    with torch.no_grad():
        outputs=bert_model(input_ids,token_type_ids=None,attention_mask=None,)
        #For eval mode, the first result of outputs is logits
        logits=outputs[0]

    predict_results=logits.detach().cpu().numpy()
    results_arrays_soft=softmax(predict_results) #Make each token predict result into softmax mode
    result_array=results_arrays_soft
    result_list=np.argmax(result_array,axis=-1)

    # #Get token predict tag
    # for i, mark in enumerate(attention_masks[0]):
    #     if mark>0:
    #         print(f'{temp_token[i]:50} {idx2tag[result_list[i]]}')
        # Build token-tag pairs
    token_tag_pairs = []
    for i, mark in enumerate(attention_masks[0]):
        if mark > 0:
            token_tag_pairs.append({
                'token': temp_token[i],
                'tag': idx2tag[result_list[i]],
                'position': i
            })

    return token_tag_pairs

# %%
predict = bert_predict("""
Tran Thi Mai Fullstack Developer - Accenture Da Nang Da Nang, Viet Nam - tran.thi.mai.02022001@gmail.com - 0987654321 - linkedin.com/in/tran-thi-mai-87654321 - github.com/tranthimai As a passionate Information Technology graduate, I excel in building robust full-stack solutions with a focus on user-centric design. I aspire to innovate in software development, delivering high-quality applications that solve real-world problems. WORK EXPERIENCE Accenture Da Nang Fullstack Developer Designed and deployed a client management system using React and NestJS, enhancing data processing efficiency. Optimized database queries with PostgreSQL to improve performance by 25%. Mar 2022 - Present Da Nang Adnovum Vietnam Software Engineer Developed secure RESTful services with Spring Boot and integrated frontend components with Vue.js. Conducted code reviews and improved CI/CD pipelines using GitLab. Jan 2020 - Feb 2022 Hanoi EDUCATION Bachelor of Information Technology (BIT) University of Science Hanoi GPA: 3.2/4.0 Sep 2016 - Jun 2020 PROJECTS Inventory Management System Description: Created a tool for tracking stock levels using Angular and Flask, with real-time updates. Outcome: Reduced inventory errors by 15% and improved restocking efficiency. Jun 2021 - Aug 2021 Social Media Platform Description: Built a platform with React and Node.js, featuring user profiles and messaging. Outcome: Enhanced user engagement by 30% through intuitive design and fast backend responses. Sep 2020 - Nov 2020 SKILLS Frontend: HTML, CSS, React, Angular, Tailwind CSS Backend: NestJS, Flask, Node.js DevOps: GitLab, Docker CERTIFICATIONS AWS Certified Solutions Architect – Associate Google Cloud Certified – Associate Cloud Engineer
""")

# %%
predict
# Out:
# [{'token': '[CLS]', 'tag': '[CLS]', 'position': 0},
#  {'token': 'T', 'tag': 'B-NAME', 'position': 1},
#  {'token': '##ran', 'tag': 'X', 'position': 2},
#  {'token': 'T', 'tag': 'I-NAME', 'position': 3},
#  {'token': '##hi', 'tag': 'X', 'position': 4},
#  {'token': 'Mai', 'tag': 'L-NAME', 'position': 5},
#  {'token': 'Full', 'tag': 'B-DESIG', 'position': 6},
#  {'token': '##sta', 'tag': 'X', 'position': 7},
#  {'token': '##ck', 'tag': 'X', 'position': 8},
#  {'token': 'Dev', 'tag': 'L-DESIG', 'position': 9},
#  {'token': '##elo', 'tag': 'X', 'position': 10},
#  {'token': '##per', 'tag': 'X', 'position': 11},
#  {'token': '-', 'tag': 'O', 'position': 12},
#  {'token': 'A', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 13},
#  {'token': '##cc', 'tag': 'X', 'position': 14},
#  {'token': '##ent', 'tag': 'X', 'position': 15},
#  {'token': '##ure', 'tag': 'X', 'position': 16},
#  {'token': 'Da', 'tag': 'B-LOC', 'position': 17},
#  {'token': 'Nan', 'tag': 'L-LOC', 'position': 18},
#  {'token': '##g', 'tag': 'X', 'position': 19},
#  {'token': 'Da', 'tag': 'O', 'position': 20},
#  {'token': 'Nan', 'tag': 'O', 'position': 21},
#  {'token': '##g', 'tag': 'X', 'position': 22},
#  {'token': ',', 'tag': 'O', 'position': 23},
#  {'token': 'V', 'tag': 'O', 'position': 24},
#  {'token': '##iet', 'tag': 'X', 'position': 25},
#  {'token': 'Nam', 'tag': 'O', 'position': 26},
#  {'token': '-', 'tag': 'O', 'position': 27},
#  {'token': 't', 'tag': 'U-EMAIL', 'position': 28},
#  {'token': '##ran', 'tag': 'X', 'position': 29},
#  {'token': '.', 'tag': 'X', 'position': 30},
#  {'token': 'th', 'tag': 'X', 'position': 31},
#  {'token': '##i', 'tag': 'X', 'position': 32},
#  {'token': '.', 'tag': 'X', 'position': 33},
#  {'token': 'ma', 'tag': 'X', 'position': 34},
#  {'token': '##i', 'tag': 'X', 'position': 35},
#  {'token': '.', 'tag': 'X', 'position': 36},
#  {'token': '02', 'tag': 'X', 'position': 37},
#  {'token': '##0', 'tag': 'X', 'position': 38},
#  {'token': '##22', 'tag': 'X', 'position': 39},
#  {'token': '##00', 'tag': 'X', 'position': 40},
#  {'token': '##1', 'tag': 'X', 'position': 41},
#  {'token': '@', 'tag': 'X', 'position': 42},
#  {'token': 'g', 'tag': 'X', 'position': 43},
#  {'token': '##mail', 'tag': 'X', 'position': 44},
#  {'token': '.', 'tag': 'X', 'position': 45},
#  {'token': 'com', 'tag': 'X', 'position': 46},
#  {'token': '-', 'tag': 'O', 'position': 47},
#  {'token': '09', 'tag': 'U-PHONE', 'position': 48},
#  {'token': '##8', 'tag': 'X', 'position': 49},
#  {'token': '##7', 'tag': 'X', 'position': 50},
#  {'token': '##65', 'tag': 'X', 'position': 51},
#  {'token': '##43', 'tag': 'X', 'position': 52},
#  {'token': '##21', 'tag': 'X', 'position': 53},
#  {'token': '-', 'tag': 'O', 'position': 54},
#  {'token': 'linked', 'tag': 'O', 'position': 55},
#  {'token': '##in', 'tag': 'X', 'position': 56},
#  {'token': '.', 'tag': 'X', 'position': 57},
#  {'token': 'com', 'tag': 'X', 'position': 58},
#  {'token': '/', 'tag': 'X', 'position': 59},
#  {'token': 'in', 'tag': 'X', 'position': 60},
#  {'token': '/', 'tag': 'X', 'position': 61},
#  {'token': 't', 'tag': 'X', 'position': 62},
#  {'token': '##ran', 'tag': 'X', 'position': 63},
#  {'token': '-', 'tag': 'X', 'position': 64},
#  {'token': 'th', 'tag': 'X', 'position': 65},
#  {'token': '##i', 'tag': 'X', 'position': 66},
#  {'token': '-', 'tag': 'X', 'position': 67},
#  {'token': 'ma', 'tag': 'X', 'position': 68},
#  {'token': '##i', 'tag': 'X', 'position': 69},
#  {'token': '-', 'tag': 'X', 'position': 70},
#  {'token': '87', 'tag': 'X', 'position': 71},
#  {'token': '##65', 'tag': 'X', 'position': 72},
#  {'token': '##43', 'tag': 'X', 'position': 73},
#  {'token': '##21', 'tag': 'X', 'position': 74},
#  {'token': '-', 'tag': 'O', 'position': 75},
#  {'token': 'g', 'tag': 'U-GITHUB', 'position': 76},
#  {'token': '##ith', 'tag': 'X', 'position': 77},
#  {'token': '##ub', 'tag': 'X', 'position': 78},
#  {'token': '.', 'tag': 'X', 'position': 79},
#  {'token': 'com', 'tag': 'X', 'position': 80},
#  {'token': '/', 'tag': 'X', 'position': 81},
#  {'token': 't', 'tag': 'X', 'position': 82},
#  {'token': '##rant', 'tag': 'X', 'position': 83},
#  {'token': '##hima', 'tag': 'X', 'position': 84},
#  {'token': '##i', 'tag': 'X', 'position': 85},
#  {'token': 'As', 'tag': 'O', 'position': 86},
#  {'token': 'a', 'tag': 'O', 'position': 87},
#  {'token': 'passionate', 'tag': 'O', 'position': 88},
#  {'token': 'Information', 'tag': 'O', 'position': 89},
#  {'token': 'Technology', 'tag': 'O', 'position': 90},
#  {'token': 'graduate', 'tag': 'O', 'position': 91},
#  {'token': ',', 'tag': 'O', 'position': 92},
#  {'token': 'I', 'tag': 'O', 'position': 93},
#  {'token': 'ex', 'tag': 'O', 'position': 94},
#  {'token': '##cel', 'tag': 'X', 'position': 95},
#  {'token': 'in', 'tag': 'O', 'position': 96},
#  {'token': 'building', 'tag': 'I-WORKING_DESCRIPTION', 'position': 97},
#  {'token': 'robust', 'tag': 'I-WORKING_DESCRIPTION', 'position': 98},
#  {'token': 'full', 'tag': 'I-WORKING_DESCRIPTION', 'position': 99},
#  {'token': '-', 'tag': 'I-WORKING_DESCRIPTION', 'position': 100},
#  {'token': 'stack', 'tag': 'I-WORKING_DESCRIPTION', 'position': 101},
#  {'token': 'solutions', 'tag': 'I-WORKING_DESCRIPTION', 'position': 102},
#  {'token': 'with', 'tag': 'I-WORKING_DESCRIPTION', 'position': 103},
#  {'token': 'a', 'tag': 'I-WORKING_DESCRIPTION', 'position': 104},
#  {'token': 'focus', 'tag': 'I-WORKING_DESCRIPTION', 'position': 105},
#  {'token': 'on', 'tag': 'I-WORKING_DESCRIPTION', 'position': 106},
#  {'token': 'user', 'tag': 'I-WORKING_DESCRIPTION', 'position': 107},
#  {'token': '-', 'tag': 'I-WORKING_DESCRIPTION', 'position': 108},
#  {'token': 'cent', 'tag': 'I-WORKING_DESCRIPTION', 'position': 109},
#  {'token': '##ric', 'tag': 'X', 'position': 110},
#  {'token': 'design', 'tag': 'I-WORKING_DESCRIPTION', 'position': 111},
#  {'token': '.', 'tag': 'I-WORKING_DESCRIPTION', 'position': 112},
#  {'token': 'I', 'tag': 'I-WORKING_DESCRIPTION', 'position': 113},
#  {'token': 'as', 'tag': 'O', 'position': 114},
#  {'token': '##pire', 'tag': 'X', 'position': 115},
#  {'token': 'to', 'tag': 'I-WORKING_DESCRIPTION', 'position': 116},
#  {'token': 'inn', 'tag': 'I-WORKING_DESCRIPTION', 'position': 117},
#  {'token': '##ova', 'tag': 'X', 'position': 118},
#  {'token': '##te', 'tag': 'X', 'position': 119},
#  {'token': 'in', 'tag': 'I-WORKING_DESCRIPTION', 'position': 120},
#  {'token': 'software', 'tag': 'I-WORKING_DESCRIPTION', 'position': 121},
#  {'token': 'development', 'tag': 'I-WORKING_DESCRIPTION', 'position': 122},
#  {'token': ',', 'tag': 'I-WORKING_DESCRIPTION', 'position': 123},
#  {'token': 'delivering', 'tag': 'I-WORKING_DESCRIPTION', 'position': 124},
#  {'token': 'high', 'tag': 'I-WORKING_DESCRIPTION', 'position': 125},
#  {'token': '-', 'tag': 'I-WORKING_DESCRIPTION', 'position': 126},
#  {'token': 'quality', 'tag': 'I-WORKING_DESCRIPTION', 'position': 127},
#  {'token': 'applications', 'tag': 'I-WORKING_DESCRIPTION', 'position': 128},
#  {'token': 'that', 'tag': 'I-WORKING_DESCRIPTION', 'position': 129},
#  {'token': 'solve', 'tag': 'I-WORKING_DESCRIPTION', 'position': 130},
#  {'token': 'real', 'tag': 'I-WORKING_DESCRIPTION', 'position': 131},
#  {'token': '-', 'tag': 'I-WORKING_DESCRIPTION', 'position': 132},
#  {'token': 'world', 'tag': 'I-WORKING_DESCRIPTION', 'position': 133},
#  {'token': 'problems', 'tag': 'I-WORKING_DESCRIPTION', 'position': 134},
#  {'token': '.', 'tag': 'L-PROJECT_DESCRIPTION', 'position': 135},
#  {'token': 'W', 'tag': 'O', 'position': 136},
#  {'token': '##OR', 'tag': 'X', 'position': 137},
#  {'token': '##K', 'tag': 'X', 'position': 138},
#  {'token': 'E', 'tag': 'O', 'position': 139},
#  {'token': '##X', 'tag': 'X', 'position': 140},
#  {'token': '##P', 'tag': 'X', 'position': 141},
#  {'token': '##ER', 'tag': 'X', 'position': 142},
#  {'token': '##IE', 'tag': 'X', 'position': 143},
#  {'token': '##NC', 'tag': 'X', 'position': 144},
#  {'token': '##E', 'tag': 'X', 'position': 145},
#  {'token': 'A', 'tag': 'U-WORKING_COMPANY_EXPERIENCES', 'position': 146},
#  {'token': '##cc', 'tag': 'X', 'position': 147},
#  {'token': '##ent', 'tag': 'X', 'position': 148},
#  {'token': '##ure', 'tag': 'X', 'position': 149},
#  {'token': 'Da', 'tag': 'O', 'position': 150},
#  {'token': 'Nan', 'tag': 'O', 'position': 151},
#  {'token': '##g', 'tag': 'X', 'position': 152},
#  {'token': 'Full', 'tag': 'B-DESIG', 'position': 153},
#  {'token': '##sta', 'tag': 'X', 'position': 154},
#  {'token': '##ck', 'tag': 'X', 'position': 155},
#  {'token': 'Dev', 'tag': 'L-DESIG', 'position': 156},
#  {'token': '##elo', 'tag': 'X', 'position': 157},
#  {'token': '##per', 'tag': 'X', 'position': 158},
#  {'token': 'Designed', 'tag': 'B-WORKING_DESCRIPTION', 'position': 159},
#  {'token': 'and', 'tag': 'I-WORKING_DESCRIPTION', 'position': 160},
#  {'token': 'deployed', 'tag': 'I-WORKING_DESCRIPTION', 'position': 161},
#  {'token': 'a', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 162},
#  {'token': 'client', 'tag': 'I-WORKING_DESCRIPTION', 'position': 163},
#  {'token': 'management', 'tag': 'I-WORKING_DESCRIPTION', 'position': 164},
#  {'token': 'system', 'tag': 'I-WORKING_DESCRIPTION', 'position': 165},
#  {'token': 'using', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 166},
#  {'token': 'Re', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 167},
#  {'token': '##act', 'tag': 'X', 'position': 168},
#  {'token': 'and', 'tag': 'I-WORKING_DESCRIPTION', 'position': 169},
#  {'token': 'N', 'tag': 'I-WORKING_DESCRIPTION', 'position': 170},
#  {'token': '##est', 'tag': 'X', 'position': 171},
#  {'token': '##J', 'tag': 'X', 'position': 172},
#  {'token': '##S', 'tag': 'X', 'position': 173},
#  {'token': ',', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 174},
#  {'token': 'enhancing', 'tag': 'I-WORKING_DESCRIPTION', 'position': 175},
#  {'token': 'data', 'tag': 'I-WORKING_DESCRIPTION', 'position': 176},
#  {'token': 'processing', 'tag': 'I-WORKING_DESCRIPTION', 'position': 177},
#  {'token': 'efficiency', 'tag': 'I-WORKING_DESCRIPTION', 'position': 178},
#  {'token': '.', 'tag': 'I-WORKING_DESCRIPTION', 'position': 179},
#  {'token': 'Op', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 180},
#  {'token': '##ti', 'tag': 'X', 'position': 181},
#  {'token': '##mized', 'tag': 'X', 'position': 182},
#  {'token': 'database', 'tag': 'I-WORKING_DESCRIPTION', 'position': 183},
#  {'token': 'que', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 184},
#  {'token': '##ries', 'tag': 'X', 'position': 185},
#  {'token': 'with', 'tag': 'I-WORKING_DESCRIPTION', 'position': 186},
#  {'token': 'Post', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 187},
#  {'token': '##g', 'tag': 'X', 'position': 188},
#  {'token': '##re', 'tag': 'X', 'position': 189},
#  {'token': '##S', 'tag': 'X', 'position': 190},
#  {'token': '##QL', 'tag': 'X', 'position': 191},
#  {'token': 'to', 'tag': 'I-WORKING_DESCRIPTION', 'position': 192},
#  {'token': 'improve', 'tag': 'I-WORKING_DESCRIPTION', 'position': 193},
#  {'token': 'performance', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 194},
#  {'token': 'by', 'tag': 'I-WORKING_DESCRIPTION', 'position': 195},
#  {'token': '25', 'tag': 'I-WORKING_DESCRIPTION', 'position': 196},
#  {'token': '%', 'tag': 'I-WORKING_DESCRIPTION', 'position': 197},
#  {'token': '.', 'tag': 'L-PROJECT_DESCRIPTION', 'position': 198},
#  {'token': 'Mar', 'tag': 'O', 'position': 199},
#  {'token': '202', 'tag': 'O', 'position': 200},
#  {'token': '##2', 'tag': 'X', 'position': 201},
#  {'token': '-', 'tag': 'O', 'position': 202},
#  {'token': 'Present', 'tag': 'L-WORKING_TIME_EXPERIENCES', 'position': 203},
#  {'token': 'Da', 'tag': 'O', 'position': 204},
#  {'token': 'Nan', 'tag': 'O', 'position': 205},
#  {'token': '##g', 'tag': 'X', 'position': 206},
#  {'token': 'Ad', 'tag': 'B-CERTIFICATION', 'position': 207},
#  {'token': '##nov', 'tag': 'X', 'position': 208},
#  {'token': '##um', 'tag': 'X', 'position': 209},
#  {'token': 'Vietnam', 'tag': 'O', 'position': 210},
#  {'token': 'Software', 'tag': 'B-DESIG', 'position': 211},
#  {'token': 'Engineer', 'tag': 'I-CERTIFICATION', 'position': 212},
#  {'token': 'Dev', 'tag': 'L-DESIG', 'position': 213},
#  {'token': '##elo', 'tag': 'X', 'position': 214},
#  {'token': '##ped', 'tag': 'X', 'position': 215},
#  {'token': 'secure', 'tag': 'O', 'position': 216},
#  {'token': 'R', 'tag': 'B-TECHSTACK_SKILLS', 'position': 217},
#  {'token': '##ES', 'tag': 'X', 'position': 218},
#  {'token': '##T', 'tag': 'X', 'position': 219},
#  {'token': '##ful', 'tag': 'X', 'position': 220},
#  {'token': 'services', 'tag': 'O', 'position': 221},
#  {'token': 'with', 'tag': 'O', 'position': 222},
#  {'token': 'Spring', 'tag': 'B-TECHSTACK_SKILLS', 'position': 223},
#  {'token': 'Bo', 'tag': 'L-TECHSTACK_SKILLS', 'position': 224},
#  {'token': '##ot', 'tag': 'X', 'position': 225},
#  {'token': 'and', 'tag': 'O', 'position': 226},
#  {'token': 'integrated', 'tag': 'O', 'position': 227},
#  {'token': 'front', 'tag': 'O', 'position': 228},
#  {'token': '##end', 'tag': 'X', 'position': 229},
#  {'token': 'components', 'tag': 'O', 'position': 230},
#  {'token': 'with', 'tag': 'O', 'position': 231},
#  {'token': 'V', 'tag': 'U-TECHSTACK_SKILLS', 'position': 232},
#  {'token': '##ue', 'tag': 'X', 'position': 233},
#  {'token': '.', 'tag': 'X', 'position': 234},
#  {'token': 'j', 'tag': 'X', 'position': 235},
#  {'token': '##s', 'tag': 'X', 'position': 236},
#  {'token': '.', 'tag': 'L-TECHSTACK_SKILLS', 'position': 237},
#  {'token': 'Con', 'tag': 'O', 'position': 238},
#  {'token': '##ducted', 'tag': 'X', 'position': 239},
#  {'token': 'code', 'tag': 'I-CERTIFICATION', 'position': 240},
#  {'token': 'reviews', 'tag': 'O', 'position': 241},
#  {'token': 'and', 'tag': 'O', 'position': 242},
#  {'token': 'improved', 'tag': 'O', 'position': 243},
#  {'token': 'C', 'tag': 'B-TECHSTACK_SKILLS', 'position': 244},
#  {'token': '##I', 'tag': 'X', 'position': 245},
#  {'token': '/', 'tag': 'I-TECHSTACK_SKILLS', 'position': 246},
#  {'token': 'CD', 'tag': 'I-CERTIFICATION', 'position': 247},
#  {'token': 'pipeline', 'tag': 'O', 'position': 248},
#  {'token': '##s', 'tag': 'X', 'position': 249},
#  {'token': 'using', 'tag': 'O', 'position': 250},
#  {'token': 'G', 'tag': 'B-TECHSTACK_SKILLS', 'position': 251},
#  {'token': '##it', 'tag': 'X', 'position': 252},
#  {'token': '##L', 'tag': 'X', 'position': 253},
#  {'token': '##ab', 'tag': 'X', 'position': 254},
#  {'token': '.', 'tag': 'L-PROJECT_DESCRIPTION', 'position': 255},
#  {'token': 'Jan', 'tag': 'O', 'position': 256},
#  {'token': '2020', 'tag': 'O', 'position': 257},
#  {'token': '-', 'tag': 'O', 'position': 258},
#  {'token': 'Feb', 'tag': 'O', 'position': 259},
#  {'token': '202', 'tag': 'O', 'position': 260},
#  {'token': '##2', 'tag': 'X', 'position': 261},
#  {'token': 'Han', 'tag': 'O', 'position': 262},
#  {'token': '##oi', 'tag': 'X', 'position': 263},
#  {'token': 'E', 'tag': 'O', 'position': 264},
#  {'token': '##D', 'tag': 'X', 'position': 265},
#  {'token': '##UC', 'tag': 'X', 'position': 266},
#  {'token': '##AT', 'tag': 'X', 'position': 267},
#  {'token': '##ION', 'tag': 'X', 'position': 268},
#  {'token': 'Bachelor', 'tag': 'I-DEG', 'position': 269},
#  {'token': 'of', 'tag': 'I-DEG', 'position': 270},
#  {'token': 'Information', 'tag': 'I-DEG', 'position': 271},
#  {'token': 'Technology', 'tag': 'I-DEG', 'position': 272},
#  {'token': '(', 'tag': 'I-DEG', 'position': 273},
#  {'token': 'B', 'tag': 'I-DEG', 'position': 274},
#  {'token': '##IT', 'tag': 'X', 'position': 275},
#  {'token': ')', 'tag': 'L-DEG', 'position': 276},
#  {'token': 'University', 'tag': 'B-UNI', 'position': 277},
#  {'token': 'of', 'tag': 'I-UNI', 'position': 278},
#  {'token': 'Science', 'tag': 'I-UNI', 'position': 279},
#  {'token': 'Han', 'tag': 'L-UNI', 'position': 280},
#  {'token': '##oi', 'tag': 'X', 'position': 281},
#  {'token': 'GP', 'tag': 'O', 'position': 282},
#  {'token': '##A', 'tag': 'X', 'position': 283},
#  {'token': ':', 'tag': 'O', 'position': 284},
#  {'token': '3', 'tag': 'U-GPA', 'position': 285},
#  {'token': '.', 'tag': 'X', 'position': 286},
#  {'token': '2', 'tag': 'X', 'position': 287},
#  {'token': '/', 'tag': 'X', 'position': 288},
#  {'token': '4', 'tag': 'X', 'position': 289},
#  {'token': '.', 'tag': 'X', 'position': 290},
#  {'token': '0', 'tag': 'X', 'position': 291},
#  {'token': 'Sep', 'tag': 'O', 'position': 292},
#  {'token': '2016', 'tag': 'O', 'position': 293},
#  {'token': '-', 'tag': 'O', 'position': 294},
#  {'token': 'Jun', 'tag': 'O', 'position': 295},
#  {'token': '2020', 'tag': 'O', 'position': 296},
#  {'token': 'PR', 'tag': 'B-PROJECT', 'position': 297},
#  {'token': '##O', 'tag': 'X', 'position': 298},
#  {'token': '##J', 'tag': 'X', 'position': 299},
#  {'token': '##EC', 'tag': 'X', 'position': 300},
#  {'token': '##TS', 'tag': 'X', 'position': 301},
#  {'token': 'In', 'tag': 'B-PROJECT', 'position': 302},
#  {'token': '##vent', 'tag': 'X', 'position': 303},
#  {'token': '##ory', 'tag': 'X', 'position': 304},
#  {'token': 'Management', 'tag': 'I-PROJECT', 'position': 305},
#  {'token': 'System', 'tag': 'L-PROJECT', 'position': 306},
#  {'token': 'Des', 'tag': 'B-PROJECT_DESCRIPTION', 'position': 307},
#  {'token': '##cription', 'tag': 'X', 'position': 308},
#  {'token': ':', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 309},
#  {'token': 'Created', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 310},
#  {'token': 'a', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 311},
#  {'token': 'tool', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 312},
#  {'token': 'for', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 313},
#  {'token': 'tracking', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 314},
#  {'token': 'stock', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 315},
#  {'token': 'levels', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 316},
#  {'token': 'using', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 317},
#  {'token': 'Ang', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 318},
#  {'token': '##ular', 'tag': 'X', 'position': 319},
#  {'token': 'and', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 320},
#  {'token': 'F', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 321},
#  {'token': '##las', 'tag': 'X', 'position': 322},
#  {'token': '##k', 'tag': 'X', 'position': 323},
#  {'token': ',', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 324},
#  {'token': 'with', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 325},
#  {'token': 'real', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 326},
#  {'token': '-', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 327},
#  {'token': 'time', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 328},
#  {'token': 'updates', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 329},
#  {'token': '.', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 330},
#  {'token': 'Out', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 331},
#  {'token': '##come', 'tag': 'X', 'position': 332},
#  {'token': ':', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 333},
#  {'token': 'Red', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 334},
#  {'token': '##uce', 'tag': 'X', 'position': 335},
#  {'token': '##d', 'tag': 'X', 'position': 336},
#  {'token': 'inventory', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 337},
#  {'token': 'errors', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 338},
#  {'token': 'by', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 339},
#  {'token': '15', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 340},
#  {'token': '%', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 341},
#  {'token': 'and', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 342},
#  {'token': 'improved', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 343},
#  {'token': 'rest', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 344},
#  {'token': '##ock', 'tag': 'X', 'position': 345},
#  {'token': '##ing', 'tag': 'X', 'position': 346},
#  {'token': 'efficiency', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 347},
#  {'token': '.', 'tag': 'L-PROJECT_DESCRIPTION', 'position': 348},
#  {'token': 'Jun', 'tag': 'O', 'position': 349},
#  {'token': '202', 'tag': 'O', 'position': 350},
#  {'token': '##1', 'tag': 'X', 'position': 351},
#  {'token': '-', 'tag': 'O', 'position': 352},
#  {'token': 'Aug', 'tag': 'O', 'position': 353},
#  {'token': '202', 'tag': 'O', 'position': 354},
#  {'token': '##1', 'tag': 'X', 'position': 355},
#  {'token': 'Social', 'tag': 'B-PROJECT', 'position': 356},
#  {'token': 'Media', 'tag': 'I-PROJECT', 'position': 357},
#  {'token': 'Platform', 'tag': 'L-PROJECT', 'position': 358},
#  {'token': 'Des', 'tag': 'B-PROJECT_DESCRIPTION', 'position': 359},
#  {'token': '##cription', 'tag': 'X', 'position': 360},
#  {'token': ':', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 361},
#  {'token': 'Built', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 362},
#  {'token': 'a', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 363},
#  {'token': 'platform', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 364},
#  {'token': 'with', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 365},
#  {'token': 'Re', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 366},
#  {'token': '##act', 'tag': 'X', 'position': 367},
#  {'token': 'and', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 368},
#  {'token': 'No', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 369},
#  {'token': '##de', 'tag': 'X', 'position': 370},
#  {'token': '.', 'tag': 'X', 'position': 371},
#  {'token': 'j', 'tag': 'X', 'position': 372},
#  {'token': '##s', 'tag': 'X', 'position': 373},
#  {'token': ',', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 374},
#  {'token': 'featuring', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 375},
#  {'token': 'user', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 376},
#  {'token': 'profiles', 'tag': 'I-CERTIFICATION', 'position': 377},
#  {'token': 'and', 'tag': 'I-PROJECT_DESCRIPTION', 'position': 378},
#  {'token': 'mess', 'tag': 'I-CERTIFICATION', 'position': 379},
#  {'token': '##aging', 'tag': 'X', 'position': 380},
#  {'token': '.', 'tag': 'L-PROJECT_DESCRIPTION', 'position': 381},
#  {'token': 'Out', 'tag': 'I-CERTIFICATION', 'position': 382},
#  {'token': '##come', 'tag': 'X', 'position': 383},
#  {'token': ':', 'tag': 'O', 'position': 384},
#  {'token': 'En', 'tag': 'B-CERTIFICATION', 'position': 385},
#  {'token': '##han', 'tag': 'X', 'position': 386},
#  {'token': '##ced', 'tag': 'X', 'position': 387},
#  {'token': 'user', 'tag': 'I-CERTIFICATION', 'position': 388},
#  {'token': 'engagement', 'tag': 'O', 'position': 389},
#  {'token': 'by', 'tag': 'I-CERTIFICATION', 'position': 390},
#  {'token': '30', 'tag': 'O', 'position': 391},
#  {'token': '%', 'tag': 'L-CERTIFICATION', 'position': 392},
#  {'token': 'through', 'tag': 'I-CERTIFICATION', 'position': 393},
#  {'token': 'in', 'tag': 'I-CERTIFICATION', 'position': 394},
#  {'token': '##tu', 'tag': 'X', 'position': 395},
#  {'token': '##itive', 'tag': 'X', 'position': 396},
#  {'token': 'design', 'tag': 'I-CERTIFICATION', 'position': 397},
#  {'token': 'and', 'tag': 'I-CERTIFICATION', 'position': 398},
#  {'token': 'fast', 'tag': 'I-CERTIFICATION', 'position': 399},
#  {'token': 'back', 'tag': 'O', 'position': 400},
#  {'token': '##end', 'tag': 'X', 'position': 401},
#  {'token': 'responses', 'tag': 'I-CERTIFICATION', 'position': 402},
#  {'token': '.', 'tag': 'L-TECHSTACK_SKILLS', 'position': 403},
#  {'token': 'Sep', 'tag': 'O', 'position': 404},
#  {'token': '2020', 'tag': 'L-CERTIFICATION', 'position': 405},
#  {'token': '-', 'tag': 'O', 'position': 406},
#  {'token': 'Nov', 'tag': 'O', 'position': 407},
#  {'token': '2020', 'tag': 'O', 'position': 408},
#  {'token': 'SK', 'tag': 'O', 'position': 409},
#  {'token': '##IL', 'tag': 'X', 'position': 410},
#  {'token': '##LS', 'tag': 'X', 'position': 411},
#  {'token': 'Front', 'tag': 'I-CERTIFICATION', 'position': 412},
#  {'token': '##end', 'tag': 'X', 'position': 413},
#  {'token': ':', 'tag': 'O', 'position': 414},
#  {'token': 'H', 'tag': 'L-CERTIFICATION', 'position': 415},
#  {'token': '##TM', 'tag': 'X', 'position': 416},
#  {'token': '##L', 'tag': 'X', 'position': 417},
#  {'token': ',', 'tag': 'O', 'position': 418},
#  {'token': 'CS', 'tag': 'L-CERTIFICATION', 'position': 419},
#  {'token': '##S', 'tag': 'X', 'position': 420},
#  {'token': ',', 'tag': 'O', 'position': 421},
#  {'token': 'Re', 'tag': 'B-TECHSTACK_SKILLS', 'position': 422},
#  {'token': '##act', 'tag': 'X', 'position': 423},
#  {'token': ',', 'tag': 'O', 'position': 424},
#  {'token': 'Ang', 'tag': 'I-CERTIFICATION', 'position': 425},
#  {'token': '##ular', 'tag': 'X', 'position': 426},
#  {'token': ',', 'tag': 'O', 'position': 427},
#  {'token': 'Tai', 'tag': 'B-CERTIFICATION', 'position': 428},
#  {'token': '##l', 'tag': 'X', 'position': 429},
#  {'token': '##wind', 'tag': 'X', 'position': 430},
#  {'token': 'CS', 'tag': 'X', 'position': 431},
#  {'token': '##S', 'tag': 'X', 'position': 432},
#  {'token': 'Back', 'tag': 'O', 'position': 433},
#  {'token': '##end', 'tag': 'X', 'position': 434},
#  {'token': ':', 'tag': 'O', 'position': 435},
#  {'token': 'N', 'tag': 'U-WORKING_COMPANY_EXPERIENCES', 'position': 436},
#  {'token': '##est', 'tag': 'X', 'position': 437},
#  {'token': '##J', 'tag': 'X', 'position': 438},
#  {'token': '##S', 'tag': 'X', 'position': 439},
#  {'token': ',', 'tag': 'O', 'position': 440},
#  {'token': 'F', 'tag': 'L-CERTIFICATION', 'position': 441},
#  {'token': '##las', 'tag': 'X', 'position': 442},
#  {'token': '##k', 'tag': 'X', 'position': 443},
#  {'token': ',', 'tag': 'O', 'position': 444},
#  {'token': 'No', 'tag': 'I-CERTIFICATION', 'position': 445},
#  {'token': '##de', 'tag': 'X', 'position': 446},
#  {'token': '.', 'tag': 'L-CERTIFICATION', 'position': 447},
#  {'token': 'j', 'tag': 'X', 'position': 448},
#  {'token': '##s', 'tag': 'X', 'position': 449},
#  {'token': 'Dev', 'tag': 'I-CERTIFICATION', 'position': 450},
#  {'token': '##O', 'tag': 'X', 'position': 451},
#  {'token': '##ps', 'tag': 'X', 'position': 452},
#  {'token': ':', 'tag': 'O', 'position': 453},
#  {'token': 'G', 'tag': 'B-TECHSTACK_SKILLS', 'position': 454},
#  {'token': '##it', 'tag': 'X', 'position': 455},
#  {'token': '##L', 'tag': 'X', 'position': 456},
#  {'token': '##ab', 'tag': 'X', 'position': 457},
#  {'token': ',', 'tag': 'O', 'position': 458},
#  {'token': 'Dock', 'tag': 'B-CERTIFICATION', 'position': 459},
#  {'token': '##er', 'tag': 'X', 'position': 460},
#  {'token': 'CE', 'tag': 'B-CERTIFICATION', 'position': 461},
#  {'token': '##RT', 'tag': 'X', 'position': 462},
#  {'token': '##IF', 'tag': 'X', 'position': 463},
#  {'token': '##IC', 'tag': 'X', 'position': 464},
#  {'token': '##AT', 'tag': 'X', 'position': 465},
#  {'token': '##ION', 'tag': 'X', 'position': 466},
#  {'token': '##S', 'tag': 'X', 'position': 467},
#  {'token': 'A', 'tag': 'I-CERTIFICATION', 'position': 468},
#  {'token': '##WS', 'tag': 'X', 'position': 469},
#  {'token': 'Certified', 'tag': 'I-CERTIFICATION', 'position': 470},
#  {'token': 'Solutions', 'tag': 'L-CERTIFICATION', 'position': 471},
#  {'token': 'Architect', 'tag': 'I-CERTIFICATION', 'position': 472},
#  {'token': '–', 'tag': 'I-CERTIFICATION', 'position': 473},
#  {'token': 'Associate', 'tag': 'L-CERTIFICATION', 'position': 474},
#  {'token': 'Google', 'tag': 'L-CERTIFICATION', 'position': 475},
#  {'token': 'Cloud', 'tag': 'L-CERTIFICATION', 'position': 476},
#  {'token': 'Certified', 'tag': 'I-CERTIFICATION', 'position': 477},
#  {'token': '–', 'tag': 'I-CERTIFICATION', 'position': 478},
#  {'token': 'Associate', 'tag': 'L-CERTIFICATION', 'position': 479},
#  {'token': 'Cloud', 'tag': 'I-CERTIFICATION', 'position': 480},
#  {'token': 'Engineer', 'tag': 'I-CERTIFICATION', 'position': 481},
#  {'token': '[SEP]', 'tag': '[SEP]', 'position': 482}]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
